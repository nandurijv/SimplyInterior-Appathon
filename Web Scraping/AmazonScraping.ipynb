# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_title(soup):
    try:
        title = soup.find("span", attrs={'id':'productTitle'})
        title_value = title.string
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""   
    return title_string

# %%
def get_price(soup):
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
        except:     
            price = ""  
    return price

# %%
def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
    return rating

# %%
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip() 
    except AttributeError:
        review_count = ""   
    return review_count

# %%
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"
    return available

# %%
if __name__ == '__main__':
 
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    URL = "https://www.amazon.com/s?k=sofa&ref=nb_sb_noss_2"
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "lxml")
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
    links_list = []
    for link in links:
        links_list.append(link.get('href'))
 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
         
        print("Product Title =", get_title(new_soup))
        print("Product Price =", get_price(new_soup))
        print("Product Rating =", get_rating(new_soup))
        print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", get_availability(new_soup))
        print()
        print()
# Out:
# Product Title = Amazon Brand – Rivet Revolve Modern Leather Sofa Couch, 80"W, Caramel
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,592 ratings
# Availability = Not Available
#
#
# Product Title = Becko Ergonomic Adjustable Office Chair with Roller Blade Wheels for Home and Office - with Breathable Mesh Backrest, Thick Comfy Cushion, Back Support, Retractable headrest & Armrests (Black)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 56 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand - Stone & Beam Westview Extra-Deep Down-Filled Sofa Couch, 89"W, Cream
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 240 ratings
# Availability = Not Available
#
#
# Product Title = CHADIOR Convertible Sectional Sofa with Reversible Chaise 77" L-Shaped Couch with Storage Ottoman Modern Linen Fabric for Small Space Living Room Apartment Grey
# Product Price =
# Product Rating = 2.7 out of 5 stars
# Number of Product Reviews = 28 ratings
# Availability = Only 9 left in stock - order soon.
#
#
# Product Title = Amazon Brand – Stone & Beam Hillman Mid-Century Sofa Couch with Wood Base and Legs, 78"W, Ivory
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 202 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Bigelow Modern Leather Sofa Couch with Wood Base, 89.4"W, Cognac / Espresso
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 85 ratings
# Availability = Not Available
#
#
# Product Title = ZINUS Josh Loveseat Sofa / Easy, Tool-Free Assembly, Beige
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 1,537 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Revolve Modern Upholstered Sofa with Reversible Sectional Chaise, 80"W, Storm Grey
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,592 ratings
# Availability = Not Available
#
#
# Product Title = Iconic Home Christophe Love Seat Sofa Velvet Upholstered Button Tufted Nailhead Trim Shelter Arm Design Silver Tone Metal Block Legs Modern Transitional, Grey
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 6 ratings
# Availability = Not Available
#
#
# Product Title = Vonanda Sofa Bed, Convertible Chair 4 in 1 Multi-Function Folding Ottoman Modern Breathable Linen Guest Bed with Adjustable Sleeper for Small Room Apartment, Dark Gray
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 886 ratings
# Availability = In Stock.
#
#
# Product Title = Serweet Sofa Bed, Convertible 5 in 1 Multifunction Adjustable Folding Ottoman, Sofa/Chair, Bed, Lounger, Sturdy Metal Frame with Linen Fabric Designed for Living Room, Office, Apartment, Bright Yellow
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 3 ratings
# Availability = In Stock.
#
#
# Product Title = ZINUS Benton Sofa Couch / Grid Tufted Cushions / Easy, Tool-Free Assembly, Stone Grey
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 1,155 ratings
# Availability = Not Available
#
#
# Product Title = Vonanda Faux Leather Sofa Couch, Mid-Century Handmade with 74 inch Couch with Comfortable Cloud Cushion and Eucalyptus Frame for Compact Living Room or Apartment, Caramel
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 6 ratings
# Availability = In Stock.
#
#
# Product Title = ZINUS Ricardo Loveseat Sofa / Tufted Cushions / Easy, Tool-Free Assembly, Dark Grey
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 1,613 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Stone & Beam Bradbury Chesterfield Tufted Loveseat Sofa Couch, 78.7"W, Navy
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 710 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Aiden Mid-Century Modern Reversible Sectional Sofa (86") - Dark Gray
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 1,070 ratings
# Availability = Not Available
#
#
# Product Title = Signature Design by Ashley - Hettinger Faux Leather Sofa, Brown
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 9 ratings
# Availability = Not Available
#
#
# Product Title = Serta Rane Convertible Sofa Bed, 66.1" W x 33.1" D x 29.5" H, Dark Gray
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 209 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Brooke Contemporary Mid-Century Modern Tufted Leather Sofa Couch, 82"W, Grey
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 194 ratings
# Availability = Not Available
#
#
# Product Title = ANONER Folding Sleeper Chair Sofa Bed Lazy Couch with Pillow, Twin Size, Light Gray
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 42 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Stone & Beam Lauren Genuine Leather Down-Filled Oversized Loveseat Sofa, 74"W, Cognac
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 1,298 ratings
# Availability = Not Available
#
#
# Product Title = Serweet Sofa Bed, Convertible 5 in 1 Multifunction Adjustable Folding Ottoman, Sofa/Chair, Bed, Lounger, Sturdy Metal Frame with Linen Fabric Designed for Living Room, Office, Apartment, Dark Gray
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 5 ratings
# Availability = In Stock.
#
#
# Product Title = Modern Bonded Leather Sectional Sofa - Small Space Configurable Couch - Black
# Product Price =
# Product Rating = 3.2 out of 5 stars
# Number of Product Reviews = 447 ratings
# Availability = Not Available
#
#
# Product Title = Signature Design by Ashley - Altari Modern Sofa, Alloy
# Product Price =
# Product Rating = 3.7 out of 5 stars
# Number of Product Reviews = 16 ratings
# Availability = Not Available
#
#
# Product Title = Fun Furnishings Toddler Flip Sofa, Dark Blue
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,007 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Cove Mid-Century Modern Tufted Leather Loveseat Sofa, 56"W, Caramel
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 370 ratings
# Availability = Not Available
#
#
# Product Title = South Shore Live-It Cozy Sectional Sofa-Bed with Storage, Gray Fog
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 103 ratings
# Availability = Not Available
#
#
# Product Title = LALIFIT Decorative Faux Cashmere Throw Blankets Soft Fluffy Classic Green Red Plaid Fringe Throw Blanket with Tassels Cozy Lightweight for Home Couch Sofa Farmhouse Outdoor Decor 50" x 60" (Christmas)
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 12 ratings
# Availability = In stock soon.
#
#
# Product Title = Sauder Manhattan Gate Sofa Table, Ivory Finish
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = In Stock.
#
#
# Product Title = Vonanda Velvet Sofa Couch, Mid Century Modern Craftsmanship 73 inch 3-Seater Sofa with High-Density Sponge Comfy Soft Cushions and 2 Bolster Pillows for Compact Living Room, Grey
# Product Price =
# Product Rating = 3.3 out of 5 stars
# Number of Product Reviews = 6 ratings
# Availability = In Stock.
#
#
# Product Title = Nouhaus Module, Sleeper Sofa Bed Couch. 7ft Luxury Convertible Sofa Futon Bed with No Roll Together Latex. Grey Woven Pull Out Couch Bed for Bedroom Couch, Small Apartment Furniture Sofas or RV Couch
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 44 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Midtown Contemporary Upholstered Sofa Couch, 92.1"W, Cream
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 141 ratings
# Availability = Not Available
#
#
# Product Title = Lexicon Vega Living Room Sofa, Light Gray
# Product Price =
# Product Rating = 3.8 out of 5 stars
# Number of Product Reviews = 42 ratings
# Availability = Not Available
#
#
# Product Title = Vonanda Faux Leather Sofa Couch, Mid-Century 73 Inch 3-Seater Sofa with 2 Bolster Pillows and Hand-Stitched Comfort Cushion for Compact Living Room, Chestnut Brown
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 14 ratings
# Availability = In Stock.
#
#
# Product Title = Signature Design by Ashley - Team Time Casual Faux Leather Power Reclining Sofa - Adjustable Headrest - Dark Brown
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 12 ratings
# Availability = Not Available
#
#
# Product Title = Lifestyle Solutions Arlington Sofas, 80.1" W x 31.9" D x 34.6" H, Charcoal Grey
# Product Price =
# Product Rating = 3.2 out of 5 stars
# Number of Product Reviews = 30 ratings
# Availability = Not Available
#
#
# Product Title = OSP Home Furnishings Russell Reversible Sectional Sofa with 2 Pillows and Coffee Finished Legs, Ivory
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 85 ratings
# Availability = Not Available
#
#
# Product Title = Sofa Arm Tray Table - Couch Armrest Tray with iPad/Phone Holder - Multi-Functional Folding Bamboo Couch Tray, Drink Holder with iPad and Phone Slots - Couch Coaster for Snacks - Organize Your Lounge
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = In Stock.
#
#
# Product Title = Kescas Sofa Bed, 5 in 1 Multi-Function Convertible Sofa Chair Folding Ottoman with Adjustable Backrest, Elegant Linen Modern Couch Bed for Living Room Office Apartment, Light Gray
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 7 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Basics Adjustable Foam Floor Sofa - Grey
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 177 ratings
# Availability = Not Available
#
#
# Product Title = Etna Products Sofa Side Table With Drawer by EasyComforts
# Product Price =
# Product Rating = 3.4 out of 5 stars
# Number of Product Reviews = 156 ratings
# Availability = Only 4 left in stock - order soon.
#
#
# Product Title = Amazon Brand – Stone & Beam Blaine Modern Sectional Sofa, 79.5"W, Navy Blue
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 296 ratings
# Availability = Not Available
#
#
# Product Title = Serta Palisades Upholstered Sofas for Living Room Modern Design Couch, Straight Arms, Soft Fabric Upholstery, Tool-Free Assembly - 73" Sofa - Beige
# Product Price =
# Product Rating = 3.4 out of 5 stars
# Number of Product Reviews = 2,121 ratings
# Availability = Not Available
#
#
# Product Title = Ainfox Ottoman Sofa Bed, 4 in 1 Multi-Use Folding Guest Bed Full Padded Lounge Couch Bed Convertible Single Sofa Chair (Deep Brown)
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 70 ratings
# Availability = Not Available
#
#
# Product Title = Novogratz Palm Springs Convertible Sofa Sleeper in Rich Linen, Sturdy Wooden Legs and Tufted Design, Blue Linen, 2182629N
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 344 ratings
# Availability = Not Available
#
#
# Product Title = Zinus Mikhail Mid-Century Sofa Couch / Ruby Red Sofa / Button Tufted Cushions / Easy, Tool-Free Assembly
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 203 ratings
# Availability = Not Available
#
#
# Product Title = Outraveler Inflatable Flocked Lounger Air Sofa Chair for Indoor Living Room and Outdoor Camping Party Picnic Travel (Double Sofa)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 54 ratings
# Availability = In Stock.
#
#
# Product Title = POLY & BARK Napa Right-Facing Sectional Sofa in Full-Grain Pure-Aniline Italian Tanned Leather in Cognac Tan
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 559 ratings
# Availability = Not Available
#
#
# Product Title = Serweet Sofa Bed, Convertible 5 in 1 Multifunction Adjustable Folding Ottoman, Sofa/Chair, Bed, Lounger, Sturdy Metal Frame with Linen Fabric Designed for Living Room, Office, Apartment, Dark Brown
# Product Price =
# Product Rating = 3.3 out of 5 stars
# Number of Product Reviews = 4 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Thomas Genuine Leather Modern Sofa Couch, 101.2"W, Chestnut
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 70 ratings
# Availability = Not Available
#
#
# Product Title =
# Product Price =
# Product Rating = 4.8 ratings
# Number of Product Reviews =
# Availability = Not Available
#
#
# Product Title = Meridian Furniture Plush Collection Modern | Contemporary Velvet Upholstered Cloud Modular Down Filled Overstuffed U-Shaped Sectional, 8-Seater, Navy
# Product Price =
# Product Rating = 3.6 out of 5 stars
# Number of Product Reviews = 4 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Sloane Mid-Century Modern Loveseat Sofa, 64.2"W, Shell
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 975 ratings
# Availability = Not Available
#
#
# Product Title = Edenbrook Willow Upholstered Loveseat with Rolled Arms – Contemporary, Casual, Cozy, and Comfortable, Sofa, Misty Gray, EH0007SOF00LG
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 53 ratings
# Availability = Not Available
#
#
# Product Title = Amazon Brand – Rivet Cove Mid-Century Modern Tufted Apartment Sofa, 72"W, Light Grey
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 370 ratings
# Availability = Not Available
#
#
# Product Title = Milliard Tri-Fold Foam Folding Mattress and Sofa Bed for Guests (Single)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 4,410 ratings
# Availability = In Stock.
#
#
# Product Title = Throw Blanket Soft Plush Bedding Sofa Warm Flannel Fleece Blankets for Kids Adult Gifts
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = In Stock.
#
#
# Product Title = Fleece Throw Blankets FY FIBER HOUSE Thick Sherpa Blanket Soft Throws Plush Cozy Baby Chenille Throw Blanket for Sofa - 60x80 Inches, Grey
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 20 ratings
# Availability = In stock soon.
#
#
# Product Title = GUPO 2inch (6Pcs) Replacement Furniture Springs for Recliner Sofa Bed Trundle
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = In stock soon.
#
#
# Product Title = Homestyles 6800-11D6-TD 5-Piece Outdoor Set, 5PC 4 Seat, Beige
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = Available to ship in 1-2 days.
